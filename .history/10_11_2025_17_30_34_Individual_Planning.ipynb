# %% [markdown]
# # Individual Project Planning
#
# - DSCI_V100-009
# - Rachel Hovestad
# - Group 42

# %%
library(repr)
library(tidyverse)
library(tidymodels)
library(dplyr)

# %% [markdown]
# ### Exploratory Data Analysis and Evaluation

# %%
players <- read_csv("players.csv")

head(players)

# %%
players_mean <- players |>
  summarise(mean_age = mean(Age, na.rm = TRUE), mean_playtime = mean(played_hours, na.rm = TRUE))

players_mean

# %% [markdown]
# Can self-described experience predict length of playtime?
